# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
from glob import glob
import IPython.display as ipd
import librosa.display

# %%
# Reading the normal audio files in an array.
data_dir = "../0db_fan/fan/id_02/normal"
norm_audio_files = glob(data_dir + '/*.wav')
x = len(norm_audio_files)
x
# Out:
# 1016

# %%
# Reading the normal audio files in an array.
data_dir1 =  "../0db_fan/fan/id_02/abnormal"
abnorm_audio_files = glob(data_dir1 + '/*.wav')
x = len(abnorm_audio_files)
x
# Out:
# 359

# %%
# Amplitude and frequency are important parameters of
# the sound and are unique for each audio.

plt.figure(figsize = (12,4))

# .load loads an audio file and decodes it into a 1-dimensional array which is a time series x ,
# and sr is a sampling rate of x . Default sris 22kHz.

data, sample_rate = librosa.load(norm_audio_files[5])

#librosa.display.waveplot(data, sr=sample_rate) # is used to plot waveform of amplitude vs time
#ipd.Audio(norm_audio_files[0]) # To play an audio.

# %%
#display Spectrogram
X = librosa.stft(data)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
plt.title("Fan Machine")
librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
# Amplitude and frequency are important parameters of
# the sound and are unique for each audio.

plt.figure(figsize = (12,4))

# .load loads an audio file and decodes it into a 1-dimensional array which is a time series x ,
# and sr is a sampling rate of x . Default sris 22kHz.

data1, sample_rate1 = librosa.load(abnorm_audio_files[5])

#librosa.display.waveplot(data1, sr=sample_rate1) # is used to plot waveform of amplitude vs time
#ipd.Audio(norm_audio_files[0]) # To play an audio.

# %%
#display Spectrogram
X = librosa.stft(data1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
plt.title("Fan Machine")
librosa.display.specshow(Xdb, sr=sample_rate1, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
y, sr = librosa.load("../0db_fan/fan/id_02/normal/00000000.wav")
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
y, sr = librosa.load('../0db_fan/fan/id_02/abnormal/00000000.wav')
plt.plot(y);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
import numpy as np
# Zooming in

n_fft = 2048
ft = np.abs(librosa.stft(y[:n_fft], hop_length = n_fft+1))
plt.plot(ft);
n0 = 0
n1 = 2000
plt.figure(figsize=(14, 5))
plt.plot(y[n0:n1])
plt.title('Spectrum');
plt.xlabel('Frequency Bin');
plt.ylabel('Amplitude');

# %%
n_fft = 2048
ft = np.abs(librosa.stft(y[:n_fft], hop_length = n_fft+1))


plt.plot(ft);
plt.title('Spectrum');
plt.xlabel('Frequency Bin');
plt.ylabel('Amplitude');

# %%
n_fft = 2048
ft = np.abs(librosa.stft(y[:n_fft], hop_length = n_fft+1))
n1=400
n2=600

plt.plot(ft[n1:n2]);
plt.title('Spectrum');
plt.xlabel('Frequency Bin');
plt.ylabel('Amplitude');

# %%
plt.scatter(ft[n1:n2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16088/280387685.py in <module>
# ----> 1 plt.scatter(ft[n1:n2])
#
# TypeError: scatter() missing 1 required positional argument: 'y'
